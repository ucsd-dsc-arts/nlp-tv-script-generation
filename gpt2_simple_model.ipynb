# %% [markdown]
# Imports

# %%
import warnings
warnings.filterwarnings("ignore")

import gpt_2_simple as gpt2
from datetime import datetime

import os

# %% [markdown]
# #### Baseline Model

# %%
sess = gpt2.start_tf_sess()

# %%
gpt2.download_gpt2()
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 390Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 6.08Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 459Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:03, 161Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 566Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 7.80Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 8.13Mit/s]

# %%
gpt2.finetune(sess,
             dataset = os.path.join('data', 'transcripts.txt'),
             model_name='124M',
             steps = 1000)
# ,
#              run_name = 'run1',
#              print_every = 10,
#              save_every = 500)
# Out:
# WARNING:tensorflow:From /home/s3mathur/.local/lib/python3.7/site-packages/gpt_2_simple/src/sample.py:17: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint checkpoint/run1/model-1000
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from checkpoint/run1/model-1000
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:07<00:00,  7.65s/it]
# dataset has 1108447 tokens
# Training...
# Saving checkpoint/run1/model-1000
# ======== SAMPLE 1 ========
# ...

# %%
gpt2.generate(sess)
# Out:
# A City Without a Poorly-guarded Transport Pickup Truck?
# (The Transport Pick-up Truck runs over the sewage flushing the building)
# (Song: "I Don't Need a Transport")
# Male Singers: ♪ We're in a hurry ♪
# ♪ To get home ♪
# ♪ Without a doubt ♪
# ♪ We're in a hurry to get home ♪
# ♪ But we're not done ♪
# ♪ So we gotta get home ♪
# ♪ It's not over yet ♪
# ♪ (Yelling) We're not done yet ♪
# ♪ (Yelling) We're in a hurry! ♪
# ♪ (Yelling) We're in a hurry! ♪
# Male Singers: ♪ We're in a hurry ♪
# ♪ To get home ♪
# ♪ Without a doubt ♪
# ♪ We're in a hurry to get home ♪
# ♪ (Yelling) We're in a hurry ♪
# ♪ To get home ♪
# ♪ Without a doubt ♪
# ♪ We're in a hurry ♪
# ♪ To get home ♪
# ♪ Without a doubt ♪
# ♪ We're in a hurry ♪
# ♪ To get home ♪
# ♪ Without a doubt ♪
# ♪ We're in a hurry ♪
# ♪ To get home ♪
# ♪ Without a doubt ♪
# ♪ We're in a hurry ♪
# ♪ To get home ♪
# ♪ Without a doubt ♪
# ♪ We're in a hurry ♪
# ♪ To get home ♪
# ♪ Without a doubt ♪
# ♪ We're in a hurry ♪
# ...

# %% [markdown]
# #### Varying Temperature

# %%
import warnings
warnings.filterwarnings("ignore")

import gpt_2_simple as gpt2
from datetime import datetime

import os

sess = gpt2.start_tf_sess()
gpt2.download_gpt2()

gpt2.finetune(sess,
             dataset = os.path.join('data', 'transcripts.txt'),
             model_name='124M',
             steps = 1000)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 392Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 37.6Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 637Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:03, 142Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 363Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 65.5Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 64.5Mit/s]
# WARNING:tensorflow:From /home/s3mathur/.local/lib/python3.7/site-packages/gpt_2_simple/src/sample.py:17: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint checkpoint/run1/model-4370
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# ...

# %%
gpt2.generate(sess,
             temperature = 0.2)
# Out:
# ♪
# ♪ I'm a big fan of her ♪
# ♪ (She's a big fan of me) ♪
# ♪ She's a big fan of me ♪
# ♪ (She's a big fan of me) ♪
# ♪ She's a big fan of me! ♪
# ♪ She's a big fan of me! ♪
# ♪ She's a big fan of me! ♪
# ♪ She's a big fan of me! ♪
# ♪ She's a big fan of me! ♪
# ♪ She's a big fan of me! ♪
# ♪ She's a big fan of me! ♪
# ♪ She's a big fan of me! ♪
# ♪ And don't you forget ♪
# ♪ That she's got an alien in her pants ♪
# ♪ (She's got an alien in her pants) ♪
# ♪ That she's got an alien in her pants! ♪
# ♪ (She's got an alien in her pants) ♪
# ♪ That she's got an alien in her pants! ♪
# (At D.E.I.)
# Doofenshmirtz: Seriously, this is going to sound like something out of a movie if you just said that again.
# (Perry jumps on the inator, sinking on the floor)
# Doofenshmirtz: Yeah!
# (On the floating screen)
# Doofenshmirtz: Tadaa!
# (Perry manages to get himself out of the inator's grasp)
# ...

# %%
gpt2.generate(sess,
             temperature = 0.5)
# Out:
# Doofenshmirtz: (laughing)
# (In the backyard...)
# Phineas: Okay, Ferb, let's see what this baby can do! (He pushes a button on a remote. The camera in the suit shoots a wide shot of the backyard as if it's a real backyard.) Oh, this is so cool! (Ferb pushes a button on another button.) Here, here, here, oooh, nice!
# (The camera goes to the exterior of the suit as the kids gasp.)
# Phineas: Oh no! We've got to do something!
# Isabella: No! No pressure!
# Baljeet: We will do nothing and will instead go about our hobby!
# Buford: This is nothing but trouble and busting!
# Baljeet: I will go do something and then something!
# Candace: But but but but but but...
# Baljeet: But then it was all for nothing!
# Candace: What do you mean, "Nothing"?
# Baljeet: It all started when I was just a little girl.
# Candace: (She pushes a button marked with an electrical hand signal) SAVE ME!
# Baljeet: I SAVE ME!
# Isabella: Save me!
# ...

# %% [markdown]
# #### Varying Temperature + top_k

# %%
gpt2.generate(sess,
             temperature = 0.7,
             top_k = 40)
# Out:
# Phineas: You know, Ferb, if we ever get those two steps in the same direction, I betcha.
# (Ferb presses a button which activates a large storage closet door in the backyard)
# Phineas: Hey, where's Perry?
# (Perry bounces up to the garage door and hops in)
# ♪ Doo be doo be doo bah ♪
# ♪ Doo be doo be doo bah ♪
# ♪ Agent P! ♪
# Major Monogram: Ah, there you are, Agent P. (Perry chatters) Remember the fabled Doo be doo bah, the persistent, flat-footed little bunny who never rests until his owner picks him up for a lazy, tired nap? That's wrong with the universe, you know. Anyway, our sources tell us that Doofenshmirtz has been shopping around for a means of defusing the Earth. We don't know what that means, but we know it's "solar coordinates". It's zero GAZ. We need you to get to the front desk and come out here. (Agent P salutes, then leaves) And don't forget to bring your -inators!
# Carl: (offscreen) Bring them back!
# ...

# %%
gpt2.generate(sess,
             temperature = 0.7,
             top_k = 40)
# Out:
# News flash: Don't touch the banana!
# Doofenshmirtz: ♪ Oh, we're banana owners, and we probably shouldn't ♪
# ♪ Touce that with a banana patoot, and you're on the way out ♪
# ♪ And for what? Drink your last cup! ♪
# ♪ (We're not selling your cup, you're gonna win this battle) ♪
# ♪ Touce that with a banana patoot, ♪
# ♪ You're gonna win this battle, ♪
# ♪ (Oh, banana patoot, banana banana banana ♪)
# ♪ You're gonna win this battle, ♪
# ♪ (Oh, banana, banana, banana...) ♪
# ♪ Yeah, and you're gonna make me ♪
# ♪ immortal! ♪
# ♪ If you ever see me up there ♪
# ♪ Don't touch the banana! ♪
# ♪ (Oh, banana, banana banana ♪) ♪
# ♪ Yeah, and you're gonna win this battle ♪
# ♪ (Oh, banana, banana banana...) ♪
# ♪ Yeah, and you're gonna win this battle, ♪
# ♪ (Oh, banana, banana banana...) ♪
# ♪ Yeah, and you're gonna win this battle, ♪
# ♪ (Oh, banana, banana banana...) ♪
# ♪ Yeah, and you're gonna win this battle, ♪
# ♪ (Yeah, banana, banana banana...) ♪
# ...

# %%
gpt2.generate(sess,
             temperature = 0.8,
             top_k = 40)
# Out:
# , all right, let's get back to business as usual.
# (Candace is still talking, in slow motions)
# Candace: What is it... What is it?
# Gretchen: We're going to the mall.
# Candace: But I can't!
# (Scene cuts to the exterior of Phineas and Ferb's building)
# Candace: Oh, Vanessa! I've had a date! You're the best girlfriend anyone has ever had!
# Vanessa: Well...
# (She kisses Phineas and starts talking to Ferb)
# Candace: I know it's akward, but who's the girl?
# Phineas: The girl's your stan?
# Candace: The girl's Stacy?
# Phineas: The girl's Linda?
# Candace: Linda? Candace? You... You know me?
#
# (Scene shifts to Doofenshmirtz Evil Incorporated)
# Doofenshmirtz: (Screams)
# (Scene shifts to Carl and Monogram)
# Major Monogram: So after all these years, (Button beeps) "Happy Birthday, Carl P" (The Welcome Screen shows Major-2 Major-2) with a special message for him. Happy birthday! Happy birthday! (Laughs) Anyway...
# ...

# %% [markdown]
# #### Varying top_p

# %%
gpt2.generate(sess,
             temperature = 0.8,
             top_p = 0.1)
# Out:
# ♪
# ♪ I'm a big fan of her ♪
# ♪ (She's a big fan of me) ♪
# ♪ She's a big fan of me ♪
# ♪ (She's a big fan of me) ♪
# ♪ She's a big fan of me! ♪
# ♪ She's a big fan of me! ♪
# ♪ She's a big fan of me! ♪
# ♪ She's a big fan of me! ♪
# ♪ She's a big fan of me! ♪
# ♪ She's a big fan of me! ♪
# ♪ She's a big fan of me! ♪
# ♪ She's a big fan of me! ♪
# ♪ She's a big fan of me! ♪
# ♪ And don't you forget ♪
# ♪ That she's got an allergy to dairy! ♪
# ♪ If you think she's being silly ♪
# ♪ (She's got an allergy to dairy!) ♪
# ♪ To the point where you could disintegrate her! ♪
# ♪ She's got an allergy to dairy! ♪
# (Cut to the backyard. Candace is watching her brothers bounce around.)
# Phineas: This is the best bounce ever!
# Buford: (offscreen) bounce! Larry, you and Stacy are busted!
# (Phineas, Ferb, Candace, and Stacy are boarding the bounce ball)
# Phineas: Come on, Ferb, 2nd Dimension guys! bounce girls!
# (They crash through the wall and emerge into the backyard.)
# ...

# %%
gpt2.generate(sess,
             temperature = 0.8,
             top_p = 1)
# Out:
# !
# Doofenshmirtz: (in background) Hey, look how cute! (to Perry) If you're not going to eat, I'll make you watch some old cartoons.
# (Cut to backyard. Phineas and the gang are eating cereal boxes.)
# Phineas: (tipping his machine) Got it!
# (Their ping pong table to reveal 2016 trending TV on a nearby hill.)
# Phineas: (to the audience) What about the new "Meap meets Pop"?
# (Cut back to D.E.I.)
# Doofenshmirtz: Oh, hey, what about that? What about that?! Did it work? I mean, uh, yeah, I-I-I'd rather you didn't know the lyrics, because I-I know it's just a song. What could be farther to that?
# (Cut back to the backyard)
# Candace: Well, it sure looks like a setup to me. (gives her sheet music)
# Stacy: (on a cell phone) I'll do it!
# Phineas: Great!
# Candace: (on another cell phone) I'll be right back!
# (On another nearby hill, under a car)
# Baljeet: Oh, my precious! It is covered with fake grass. (to Phineas and Ferb) Jeez, what's with the fuss?
# ...

# %%
gpt2.generate(sess,
             temperature = 0.8,
             top_p = 10)
# Out:
#  mine.
# Phineas: I don't remember using it.
# Jeremy: No, you forgot to bring it up.
# Phineas: Are you sure you don't wanna play through?
# Jeremy: Uh...
# Phineas: Oh, all right. Then, we can't miss the big reveal.
# (counter appears in the top-right corner)
# Baljeet: What is that big, scary machine that was?
# Buford: It's the T-Rex! The roar it creates.
# (Right after Candace finishes her trap, the T-Rex flies through the door of the house)
# Phineas: Good thing we didn't have any spare parts. We're going to need a bigger claw.
# (Ferb gets into the machine, and pulls on the ropes, which activates the machine. Phineas gets into the machine, and tries to break the claw. Buford gets into the machine, and pulls on the ropes. The claw punches Buford, and he lands on the pavement below him. The T-Rex crashes through the house, and Phineas gets into the driver's seat.)
# Buford: Can I get you a deal?
# ...

# %%
gpt2.generate(sess,
             temperature = 0.8,
             top_p = 100)
# Out:
# !
# (Cut to the hallway. Phineas, Isabella and Ferb are in the ladies' room and talking while Perry watches them.)
# Phineas: Hmm...
# Isabella: It's like my life has been a blur sheesh!
# Phineas: Try riding the Allspoon 2000!
# (Ferb gets in a cab and takes Phineas and Isabella to their house.)
# Phineas: Lady, are you ready? (He and Ferb sits on the couch, and she sets the box under the bed.) You know, this morning I was in the bathroom and you weren't.
# Lady: I will get the heck out of your box.
# Phineas: In your box? (activates a cage that crawls under the box) Good. (The box escapes from under the bed and escapes again.) Bad doggy!
# (Cut back to Perry. He puts on the fedora. He takes down the back of the box that he had earlier.)
# Perry: (chatters angrily)
# (Cut to the front door. Linda and Candace come out. Linda is on the phone waiting for them.)
# Linda: They told me they were gonna come look!
# ...

# %%
gpt2.generate(sess,
             temperature = 0.8,
             top_p = 0.1,
             top_k = 40)
# Out:
# Phineas: (to Ferb) Hey Ferb, what do you think of this?
# (Ferb says something along the lines of, "Is it a dream?" and Phineas smiles.)
# Phineas: AAAAAAAAAAAAAAAHHHHH!!!
# (The ship goes into warp state and begins to flyigate around the galaxy. One of the ships is destroyed and all the ships fall from the sky. One of the ships isettes cuts out, showing the end of the ship sailing towards the Earth.)
# Phineas: And so our friend, the little friend, is the galaxy changed. He became my best friend! You may ask? I have no idea. But you know what's really important? (Briefly, but loudly, his voice fades out.)
# Candace: (Talking on the phone) Boys, I'm telling you, it's a miracle, that Ferb's dad can hear us! Anyway, you're probably wondering why I'm here. Well, I'm not really here. I'm here to see the movie.
# Boy with remote: (takes picture of Phineas)
# Candace: What?! No...! What's the?! (Gasps) Jeremy's here! Hey, look! Ferb's here!
# ...

# %% [markdown]
# #### Defining a Prefix

# %%
gpt2.generate(sess,
             temperature = 0.7,
             top_p = 0.1,
             top_k = 40,
             prefix = "Isabella")
# Out:
# Isabella: (in her head) Well, I guess I'm on to the song.
# (Cut to:)
# ♪ Doofenshmirtz Evil Incorporated ♪
# (Perry lands down in the Tri-State Area, but his tail gazes straight at Doof)
# Doofenshmirtz: What? Oh, Perry the Platypus. How suddenly, it's hopeless. Well, the treadmill is almost back. (turns the treadmill on) Wait, wait, wait, uh... (tiresia sputtering) Wait, wait, wait, wait!
# (Perry is trapped, with the tail sticking out of his pants.)
# Doofenshmirtz: Oh, no! (reaches over his shoulder and pushes it to the back of the house with his foot, stops pushing) Oh, no, no, no, no, no, no! (runs off) Oh, no, no, no, no! (comes back to life and stretches.) How did you get over there? (Perry comes out of his hole and slams into Doofenshmirtz on the head again.)
# (Cut back to the OWCA agents in the OWCA headquarters. The robots are still fighting the Doof robots.)
# Doofenshmirtz: You're getting it. You're messing up my day.
# ...

# %%
gpt2.generate(sess,
             temperature = 0.7,
             top_p = 0.1,
             top_k = 40,
             prefix = "Isabella: What'cha doing?")
# Out:
# Isabella: What'cha doing?
# Phineas: We're building a supercomputer to build all of our favorite TV shows.
# Baljeet: Oh, that is so sweet!
# Phineas: We're really looking forward to meeting you, too!
# Buford: (Working on a model of a car) What are you doing?
# Phineas: I'm filling in for Isabella while she's at it.
# (Buford and Baljeet walk away)
# Phineas: Hey, Buford. Where's Buford?
# Buford: I joined him at a "do whatever it is" party. Now where do I go?
# Phineas: You're the famous chef, right?
# Buford: Yeah, that's where you get the big guns. I use them all the time.
# Phineas: Okay, let's run some numbers. If we start with the normal attrition rate, and then we add the part time labor, that would bring in foreign exchange for instance. Or pass on some of that to your TV or radio.
# ...

# %%
gpt2.generate(sess,
             temperature = 0.7,
             top_p = 0.1,
             top_k = 40,
             prefix = "Isabella: Whatcha doin'?")
# Out:
# Isabella: Whatcha doin'?
# Phineas: Oh, hi, Isabella.
# Isabella: Cool hat, Phineas.
# Phineas: Thanks. (To Ferb) Isabella, you wanna join us for our man cave?
# Isabella: (Gasps) Awesome!
# Isabella: You betcha!
# (Song: Man Cave)
# ♪ You're the only one that follows ♪
# ♪ Man, cave, cave ♪
# ♪ You say you don't have a caveman? ♪
# ♪ Man, cave, cave ♪
# ♪ You think you don't belong on earth ♪
# ♪ Man, cave, cave ♪
# ♪ You're a total anomaly ♪
# ♪ But just because we can't find you ♪
# ♪ Not everyone can sing the manilla song ♪
# ♪ You're a total anomaly ♪
# ♪ In case you're wondering ♪
# ♪ You're not in a uniform, you're in a cave ♪
# ♪ You're in a cave"?
# (Ferb does so easily)
# ♪ No, I'm not in a uniform ♪
# ♪ No, I'm not in a uniform, ♪
# ♪ I'm just a dutch boy with a caveman look ♪
# ♪ I'm in a cave, I'm in a cave ♪
# ♪ You're in a cave, you're in a cave ♪
# (Ferb notes his own voice)
# Isabella: (She's taking it as a cue) Hi Phineas. Whatcha doin'?
# ...

# %%
gpt2.generate(sess,
             temperature = 0.7,
             top_p = 0.1,
             top_k = 40,
             prefix = "Candace: Mom")
# Out:
# Candace: Mom, Mom!
# Linda: What are you guys up to?
# Candace: We're making our move! (leaves)
# Linda: You know, you could come closer to the monster.
# Phineas: Wait! (at Ferb) Ferb, I know what we're gonna do today!
# (Cut to the gate. Candace, still holding her phone, is walking up the stairs)
# Candace: Seriously? It's not like you and your brothers are up to anything and it seems like only dad's coming to take us!
# Linda: What? (closes phone) Oh, the beautiful thing is I can bust them now!
# Candace: Well, I can definitely bust them now. (gasps) I know. (puts phone down) That's it. I'm gonna call them! (hangs up, then calls aneurism) Mom!
# (Cut to the living room where Buford is still freaking out)
# Baljeet: Buford, no! Buford, no!
# Buford: (gasps) I am no help.
# Baljeet: What?
# Buford: (his voice is hoarse) It is none of your concern.
# Baljeet: That is all of it?
# Buford: (gasps) Well, it is not my problem!
# Baljeet: No, it is not!
# Buford: Shut it.
# ...

# %%
gpt2.generate(sess,
             temperature = 0.7,
             top_p = 0.1,
             top_k = 40,
             prefix = "(The scene opens up")
# Out:
# (The scene opens up with a view of the Flynn-Fletcher house.)
# Phineas: So the way I see it, the solid fuel rockets kick in at the mall's parking lot. Then, we release the snakes during the corkscrew at the interstate. I'll be right here.
# (Phineas and Ferb is in the backyard, working on the super-cooling system. Candace is on the phone with Stacy.)
# Candace: Guys, I'm mom. But it's 9:00 A.M. and I'm in the living room.
# Phineas: How's the garage?
# Candace: (dusts herself) All right, let's get things started.
# (She goes to the couch and opens the door.)
# Candace: Mom, you've gotta see what Phineas and Ferb have built in the garage.
# Linda: What's that?
# Candace: That's very nice, Mom. Come on in.
# Linda: What's that?
# Candace: They've got an...Their brand new garage.
# Linda: (tries to lift the frame) Oh, that's best.
# Candace: They've got an old school garage.
# Linda: Best garage ever!
# ...

# %%
gpt2.generate(sess,
             temperature = 0.7,
             top_p = 0.1,
             top_k = 40,
             prefix = "(The scene opens up to the backyard")
# Out:
# (The scene opens up to the backyard)
# Phineas: Okay, gang, time to start the Accelerator-inator.
# (Cut to Isabella's living room)
# Baljeet: (to Baljeet) You are my co-host.
# Isabella: my co-host? (sits on Baljeet's bed) Co-host! Okay, here's your monitor.
# Baljeet: (rolls down the window) D-d-d, I woke up, I don't see what started it, I don't see anything.
# Phineas: Okay, everyone, follow me! We're almost there!
# (A car is heard whirring.)
# Baljeet: Miiiindfliiip! (sits down) Curse you, Tri-State Area, L.O.V.E.M.U.F.F.I.N.!
# (Cut to the backyard.)
# Isabella: Isabella, you've got to tell Candace what she did.
# Candace: (to Baljeet) Yoo-hoo! (Candace stutters.)
# Phineas: Candace, what are you doing?
# Candace: (stops shaking) Wait a minute, what's going on?
# Phineas: She's an adult.
# Candace: I know. (at Ferb) Ferb, I'm your grown-up now.
# (Candace spits out her breakfast cereal.)
# (Cut to the house.)
# ...

# %%
gpt2.generate(sess,
             temperature = 0.7,
             top_p = 0.1,
             top_k = 40,
             prefix = "(The scene opens up with Phineas")
# Out:
# (The scene opens up with Phineas and Ferb in a cave with no electricity in it.)
# Phineas: Hey, where's Perry?
#
# (Cut to Perry's lair where Carl is hiding out a hole in the wall.)
# Carl: (offscreen) Uh, sir, I...I'd like to... (drove over by Perry's chair with a saw) but I have...my...sires are...doubtless.
# Major Monogram: (offscreen) Uh, Carl, you too, have a spot in this thread.
# Carl: (offscreen) A shot of me in your doctor's room.
# Major Monogram: , that's not very nice, Carl.
# Carl: (offscreen)  You said it'd be "nice".
# Major Monogram: , it's not, I just want to gout.
# Carl: (offscreen)  Gout.
# Major Monogram: , I'll take that.
# Carl: (offscreen)  Ugh.
# Major Monogram: , I'll talk to you later.
# Carl: (offscreen)  Later.
# Major Monogram: , but we're gonna need a scanner and some prints.
# Carl: (offscreen)  Later.
# Phineas: (offscreen)  So, how is it you took out the refrigerator?
# Major Monogram: (shakes himself awake) Oh, yeah, I guess I did.
# ...

# %%
gpt2.generate(sess,
             temperature = 0.7,
             top_p = 0.1,
             top_k = 40,
             prefix = "(The scene opens up with Phineas, Ferb, and their friends all in the backyard")
# Out:
# (The scene opens up with Phineas, Ferb, and their friends all in the backyard, with Isabella following them.)
# Isabella: Hi guys! Whatcha doin'?
# Phineas: Oh, hi, Isabella! come on up, come on up. You know, when you two asked me if I'd marry the guy with my confession and I told ya, ya, I'd tell ya. I'd also like you to see, dat is fo'en real!
# Isabella: (yelling) Ow!
# (Cut to:)
# ♪ Doofenshmirtz Evil Incorporated! ♪
# (Perry breaks a window, and gets trapped.)
# Doofenshmirtz: (Screaming)
# (Cut to a warehouse, where Agent P and Swiss Reindenghand take turns trapped.)
# ...

# %%
gpt2.generate(sess,
             temperature = 0.7,
             top_p = 0.1,
             top_k = 40,
             prefix = "(The scene opens up with Phineas and Ferb in the backyard)")
# Out:
# (The scene opens up with Phineas and Ferb in the backyard)
# Phineas: Okay, guys. Are you ready for the race?
# Candace: Wait, what?
# Phineas: Wait, you got here first?
# (The camera zooms in on Buford as Buford rolls his eyes.)
# Buford: You see, here at the Combine we're all built to meet the most basic of specs specs: YouTubers like Buford.
# Baljeet: So you are just saying your nerd is a little bit of a beast.
# Buford: (gasps)
# Isabella: So I see. So it will be a good thing we get out of it, huh?
# Phineas: Yeah, it's a good thing we get. What about Ferb?
# Ferb: (runs out)
# Phineas: Hey, where's Perry?
# (Scene switches to Perry's lair, where he enters through a tube)
# Major Monogram: Good morning, Agent P. The evil Dr. Doofenshmirtz is up to his old tricks. For reasons completely unknown, he's purchased a giant airship or blimp, as the kids say. Your mission is to find out why, and if necessary, put a stop to it. (Perry glares)
# ...

# %% [markdown]
# #### 2000 Steps

# %%
import gpt_2_simple as gpt2
sess = gpt2.start_tf_sess()
gpt2.download_gpt2()

gpt2.finetune(sess,
             dataset = os.path.join('data', 'transcripts.txt'),
             model_name='124M',
             steps = 2000)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 383Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 39.7Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 680Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:01, 309Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 399Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 16.5Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 30.3Mit/s]
# WARNING:tensorflow:From /home/s3mathur/.local/lib/python3.7/site-packages/gpt_2_simple/src/sample.py:17: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint checkpoint/run1/model-3000
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# ...
